# %%
import sys
import os

import plotly.express as px
import plotly.offline as pyo

import numpy as np
import pandas as pd
pd.options.plotting.backend = "plotly"

import os.path

sys.path.insert(1, '/u/aedinge/Twitter_Scraping')

# read processed sample data
sampled = pd.read_pickle("/l/mesur/aedinge/monkeypox_twitter/010sample_091222.pkl")
print(sampled.columns)
# Out:
# Index(['index', 'created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'source', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo',
#        'coordinates', 'place', 'contributors', 'is_quote_status',
#        'retweet_count', 'favorite_count', 'favorited', 'retweeted',
#        'possibly_sensitive', 'lang', 'extended_entities', 'quoted_status_id',
#        'quoted_status_id_str', 'quoted_status_permalink', 'quoted_status',
#        'withheld_in_countries', 'scopes', 'withheld_scope',
#        'withheld_copyright', 'date', 'text_proc', 'text_proc_length',
#        'hover_text', 'size', 'wk', 'y', 'x', 'k_means_category', 'time_color'],
#       dtype='object')

# %%
sampled['log_rt'] = sampled['retweet_count'].apply(lambda x:np.log10(x))

cluster_names = {
    0:'Noise - Outside', 
    1:'Noise - Middle', 
    2:'Case reports', 
    3:'Transmissibility, MSM communities', 
    4:'WHO Emergency', 
    5:'Vaccines', 
    6:'Monkeypox vs. Covid'
}

sampled['label'] = sampled['k_means_category'].apply(lambda x: cluster_names[x])

# %%
# setting up color map for plotting with standardized cluster colors across graphics
categories = set(sampled['k_means_category'])
col = px.colors.qualitative.Plotly[:len(categories)]
gray = '#BAB0AC'

color_map = dict(zip(categories,  col))
print(color_map)
# Out:
# {0: '#636EFA', 1: '#EF553B', 2: '#00CC96', 3: '#AB63FA', 4: '#FFA15A', 5: '#19D3F3', 6: '#FF6692'}

# %%
# color by label name
# setting up color map for plotting with standardized cluster colors across graphics
categories = cluster_names.values()
col = px.colors.qualitative.Plotly[:len(categories)]
gray = '#BAB0AC'

color_map_l = dict(zip(categories,  col))
print(color_map_l)
# Out:
# {'Noise - Outside': '#636EFA', 'Noise - Middle': '#EF553B', 'Case reports': '#00CC96', 'Transmissibility, MSM communities': '#AB63FA', 'WHO Emergency': '#FFA15A', 'Vaccines': '#19D3F3', 'Monkeypox vs. Covid': '#FF6692'}

# %%
fig = px.histogram(sampled, 
                   x="log_rt", 
                   color="label",
                   opacity=0.9,
                   log_y=True,
                   facet_col="label",
                   facet_col_wrap=2,
                   color_discrete_map=color_map_l,
                   title = "Topic Retweet Distributions"
                  )

fig.update_layout(
    autosize=False,
    width=900,
    height=900,
)

fig.update_layout({
        'plot_bgcolor': 'rgba(0, 0, 0, 0)',
        'paper_bgcolor': 'rgba(0, 0, 0, 0)',
})

fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1
0,null,null,null,null,null,1.4471580313422192,null,null,null,0.3010299956639812,null,null,null,null,0.3010299956639812,null,null,null,null,null,0.9030899869919435,null,null,null,null,null,null,null,null,null,null,null,null,0.0,null,null,0.0,null,null,null,null,0.0,null,null,2.401400540781544,null,0.0,null,null,null,null,0.6020599913279624,null,0.0,null,null,null,null,0.0,null,null,null,null,null,0.3010299956639812,null,null,null,null,null,null,null,null,0.0,0.47712125471966244,null,null,null,null,0.0,null,null,null,null,null,null,null,null,null,0.0,0.0,null,null,null,null,null,0.47712125471966244,null,null,null,null,null,null,null,0.47712125471966244,1.3617278360175928,null,null,null,null,0.0,null,null,0.6020599913279624,null,null,0.3010299956639812,0.47712125471966244,nu ...

# %%
fig = px.histogram(sampled, 
                   x="log_rt", 
                   color="label",
                   opacity=0.6,
                   log_y=True,
                   marginal="violin",
                   color_discrete_map=color_map_l,
                  )

fig.update_layout(
    autosize=False,
    width=900,
    height=900,
)

fig.update_layout({
        'plot_bgcolor': 'rgba(0, 0, 0, 0)',
        'paper_bgcolor': 'rgba(0, 0, 0, 0)',
})

fig.update_layout(barmode='overlay')

fig.show()
# Out:
# <div>                            <div id="89ddd677-3a81-48c0-82c3-07b01929e66d" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89ddd677-3a81-48c0-82c3-07b01929e66d")) {                    Plotly.newPlot(                        "89ddd677-3a81-48c0-82c3-07b01929e66d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"label=Monkeypox vs. Covid<br>log_rt=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Monkeypox vs. Covid","marker":{"color":"#FF6692","opacity":0.6,"pattern":{"shape":""}},"name":"Monkeypox vs. Covid","offsetgroup":"Monkeypox vs. Covid","orientation":"v","showlegend":true,"x":[null,1.146128035678238,null,null,null,0.0,0.8450980400142568,null,null,null,null,null,null,0.47712125471966244,null,null,null,null,null,null,null,null,0.6020599913279624,0.0,null,0.0,null,null,null,0.6989700043360189,null,null,null,null,null,0.6020599913279624,null,null,null,1.255272505103306,null,0.3010299956639812,null,null,0.0,null,null,null,0.0,null,null,null,0.47712125471966244,null,null,null,null,null,null,null,null,null,null,0.0,null,null,0.3010299956639812,null,null,null,null,null,0.0,null,null,0.0,null,null,null,null,null,null,null,0.0,null,null,1.5314789170422551,null,0.8450980400142568,0.0,null,null,null,null,0.6020599913279624,null,null,null,null,null,null,null,0.0,null,null,null,null,null,null,null,null,null,0.0,null,null,null,null,null,null,null,null,null,null,null,null,0.0,null,0.7781512503836436,0.3010299956639812,3.0269416279590295,null,null,1.1760912590556813,null,null,0.0,null,null,null,0.0,null,0.0,null,null,null,null,null,null,0.0,null,null,0.47712125471966244,null,null,null,null,null,null,null,null,null,null,null,null,null,1.0,null,null,0.47712125471966244,null,0.0,null,0.0,null,null,null,null,null,null,null,null,null,0.47712125471966244,0.47712125471966244,null,0.0,0.3010299956639812,0.0,null,null,0.47712125471966244,null,null,null,null,null,null,0.0,null,0.0,null,null,0.0,null,0.3010299956639812,null,null,null,null,null,null,null,0.0,null,null,0.0,null,null,null,null,null,null,null,null,null,null,0.0,null,null,null,null,null,null,null,0.0,null,null,null,null,0.0,null,null,null,null,null,0.0,null,null,null,null,null,null,null,null,0.0,null,null,null,null,null,null,0.6020599913279624,null,null,null,null,null,null,null,null,0.0,0.9542425094393249,null,0.3010299956639812,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.3010299956639812,0.0,null,0.0,null,null,0.0,null,null,null,null,null,null,null,null,null,0.3010299956639812,null,null,null,null,null,null,null,null,null,0.0,null,null,null,null,null,null,null,0.0,0.0,null,null,null,0.7781512503836436,0.7781512503836436,null,0.6989700043360189,null,0.0,null,null,null,null,null,null,null,0.7781512503836436,null,null,null,null,null,null,null,null,null,0.6020599913279624,null,null,null,null,null,null,null,null,0.0,null,null,null,null,null,0.0,null,0.9030899869919435,null,null,null,null,null,null,0.0,null,null,null,null,null,1.4471580313422192,null,null,null,0.3010299956639812,null,null,null,null,0.3010299956639812,null,null,null,null,null,0.9030899869919435,null,null,null,null,null,null,null,null,null,null,null,null,0.0,null,null,0.0,null,null,null,null,0.0,null,null,2.401400540781544,null,0.0,null,null,null,null,0.6020599913279624,null,0.0,null,null,null,null,0.0,null,null,null,null,null,0.3010299956639812,null,null,null,null,null,null,null,null,0.0,0.47712125471966244,null,null,null,null,0.0,null,null,null,null,null,null,null,null,null,0.0,0.0,null,null,null,null,null,0.47712125471966244,null,null,null,null,null,null,null,0.47712125471966244,1.3617278360175928,null,null,null,null,0.0,null,null,0.6020599913279624,null,null,0.3010299956639812,0.47712125471966244,nu ...

# %%
fig = px.violin(
    sampled, 
    y="log_rt", 
    x="label", 
    color="label", 
    box=False, 
    points="all",
    color_discrete_map=color_map_l,
    title="Topic Retweet Distributions"
)

fig.update_layout({
        'plot_bgcolor': 'rgba(0, 0, 0, 0)',
        'paper_bgcolor': 'rgba(0, 0, 0, 0)',
})


fig.update_yaxes(title='Log Number of Retweets')

fig.update(layout_showlegend=False)

fig.show()
# Out:
# <div>                            <div id="c6cab246-cbbc-4e3f-94ec-8d24a06b5b75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6cab246-cbbc-4e3f-94ec-8d24a06b5b75")) {                    Plotly.newPlot(                        "c6cab246-cbbc-4e3f-94ec-8d24a06b5b75",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"label=%{x}<br>log_rt=%{y}<extra></extra>","legendgroup":"Monkeypox vs. Covid","marker":{"color":"#FF6692"},"name":"Monkeypox vs. Covid","offsetgroup":"Monkeypox vs. Covid","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypox vs. Covid","Monkeypo ...

# %%
len(sampled[sampled['retweet_count']!=0])
